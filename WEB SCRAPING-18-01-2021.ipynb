# %% [markdown]
# # 1. Write a python program to display all the header tags from ‘en.wikipedia.org/wiki/Main_Page’.

# %%
#importing the libraraies
from bs4 import BeautifulSoup
import requests

# %% [raw]
# First let's write some code to grab the HTML from the web page, and look at how we can start parsing through it. The following code will send a GET request to the web page we want, and create a BeautifulSoup object with the HTML from that page:

# %%
#Fetch the main URL HTML code.
page1=requests.get("https://en.wikipedia.org/wiki/Main_Page")

# %%
#Feed that HTML to BeautifulSoup
page1.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Wikipedia, the free encyclopedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"YAT2eApAMNUAAKaATHAAAAAF","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Main_Page","wgTitle":"Main Page","wgCurRevisionId":987965326,"wgRevisionId":987965326,"wgArticleId":15580374,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Main_Page","wgRelevantArticleId":15580374,"wgIsProbablyEditable":!1,"wgRelevantPageIsPro
# ...

# %%
soup=BeautifulSoup(page1.content,'html.parser')

# %%
#while find_all returns a list of all matches.

titles1=[]
titles=soup.find_all('h2', class_="mp-h2")
titles[0:4]
# Out:
# [<h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>,
#  <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>,
#  <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>,
#  <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>]

# %%
#extract the data from h2 and class="mp-h2"
for i in titles:
    titles1.append(i.get_text().replace("\n",""))
titles1
# Out:
# ["From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "From today's featured list",
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages']

# %%
#create a dataframe and svae the result in the form of dataframe
import pandas as pd
ti=pd.DataFrame({})
ti['headtag']=titles1

# %%
ti
# Out:
#                          headtag
# 0  From today's featured article
# 1               Did you know ...
# 2                    In the news
# 3                    On this day
# 4     From today's featured list
# 5       Today's featured picture
# 6       Other areas of Wikipedia
# 7    Wikipedia's sister projects
# 8            Wikipedia languages

# %%
#same the dataframe in the form of csv files
ti.to_csv("q1.csv", index= False)

# %% [markdown]
# # 2. Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. Name, IMDB rating, Year of release) and save it in form of a CSV file.

# %%
from bs4 import BeautifulSoup
import requests

# %% [raw]
# First let's write some code to grab the HTML from the web page, and look at how we can start parsing through it. The following code will send a GET request to the web page we want, and create a BeautifulSoup object with the HTML from that page:

# %%
#Fetch the main URL HTML code.
page2=requests.get("https://www.imdb.com/search/title/?count=100&groups=top_1000&sort=user_rating")

# %%
#Feed that HTML to BeautifulSoup
page2.content
# Out:
# b'\n\n<!DOCTYPE html>\n<html\n    xmlns:og="http://ogp.me/ns#"\n    xmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n         \n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///?src=mdot">\n\n\n\n        <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};</script>\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>\n        <title>IMDb &quot;Top 1000&quot;\n(Sorted by IMDb Rating Descending) - IMDb</title>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>\n<script>\n    if (typeof uet == \'function\') {\n      uet("be", "LoadTitle", {wb: 1});\n    }\n</scrip
# ...

# %% [raw]
# #You can also provide different arguments to find_all, such as regular expressions or tag attributes to filter your search as specifically as you want.

# %%
soup=BeautifulSoup(page2.content,'html.parser')

# %%
heds = soup.find_all('h3',class_="lister-item-header")

# %%
links = []
for h in heds:
    a = h.find('a')
    links.append(a.text)

# %%
links
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Dark Knight',
#  'The Godfather: Part II',
#  '12 Angry Men',
#  'The Lord of the Rings: The Return of the King',
#  'Pulp Fiction',
#  "Schindler's List",
#  'Inception',
#  'Fight Club',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Forrest Gump',
#  'Il buono, il brutto, il cattivo',
#  'Soorarai Pottru',
#  'The Lord of the Rings: The Two Towers',
#  'The Matrix',
#  'Goodfellas',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  "One Flew Over the Cuckoo's Nest",
#  'Hamilton',
#  'Gisaengchung',
#  'Interstellar',
#  'Cidade de Deus',
#  'Sen to Chihiro no kamikakushi',
#  'Saving Private Ryan',
#  'The Green Mile',
#  'La vita è bella',
#  'Se7en',
#  'The Silence of the Lambs',
#  'Star Wars',
#  'Seppuku',
#  'Shichinin no samurai',
#  "It's a Wonderful Life",
#  'Joker',
#  'Whiplash',
#  'The Intouchables',
#  'The Prestige',
#  'The Departed',
#  'The Pianist',
#  'Gladiator',
# ...

# %%
titles1=[]
titles=soup.find_all('h3', class_="lister-item-header")
titles[0:4]
# Out:
# [<h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">1.</span>
#  <a href="/title/tt0111161/">The Shawshank Redemption</a>
#  <span class="lister-item-year text-muted unbold">(1994)</span>
#  </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">2.</span>
#  <a href="/title/tt0068646/">The Godfather</a>
#  <span class="lister-item-year text-muted unbold">(1972)</span>
#  </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">3.</span>
#  <a href="/title/tt0468569/">The Dark Knight</a>
#  <span class="lister-item-year text-muted unbold">(2008)</span>
#  </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">4.</span>
#  <a href="/title/tt0071562/">The Godfather: Part II</a>
#  <span class="lister-item-year text-muted unbold">(1974)</span>
#  </h3>]

# %%
for i in titles:
    
    titles1.append(i.get_text().replace("\n",""))
titles1
# Out:
# ['1.The Shawshank Redemption(1994)',
#  '2.The Godfather(1972)',
#  '3.The Dark Knight(2008)',
#  '4.The Godfather: Part II(1974)',
#  '5.12 Angry Men(1957)',
#  '6.The Lord of the Rings: The Return of the King(2003)',
#  '7.Pulp Fiction(1994)',
#  "8.Schindler's List(1993)",
#  '9.Inception(2010)',
#  '10.Fight Club(1999)',
#  '11.The Lord of the Rings: The Fellowship of the Ring(2001)',
#  '12.Forrest Gump(1994)',
#  '13.Il buono, il brutto, il cattivo(1966)',
#  '14.Soorarai Pottru(2020)',
#  '15.The Lord of the Rings: The Two Towers(2002)',
#  '16.The Matrix(1999)',
#  '17.Goodfellas(1990)',
#  '18.Star Wars: Episode V - The Empire Strikes Back(1980)',
#  "19.One Flew Over the Cuckoo's Nest(1975)",
#  '20.Hamilton(2020)',
#  '21.Gisaengchung(2019)',
#  '22.Interstellar(2014)',
#  '23.Cidade de Deus(2002)',
#  '24.Sen to Chihiro no kamikakushi(2001)',
#  '25.Saving Private Ryan(1998)',
#  '26.The Green Mile(1999)',
#  '27.La vita è bella(1997)',
#  '28.Se7en(1995)',
# ...

# %%
year=[]
y=soup.find_all('span', class_="lister-item-year text-muted unbold")
y[0:4]
# Out:
# [<span class="lister-item-year text-muted unbold">(1994)</span>,
#  <span class="lister-item-year text-muted unbold">(1972)</span>,
#  <span class="lister-item-year text-muted unbold">(2008)</span>,
#  <span class="lister-item-year text-muted unbold">(1974)</span>]

# %%
for i in y:
    year.append(i.text)
year
# Out:
# ['(1994)',
#  '(1972)',
#  '(2008)',
#  '(1974)',
#  '(1957)',
#  '(2003)',
#  '(1994)',
#  '(1993)',
#  '(2010)',
#  '(1999)',
#  '(2001)',
#  '(1994)',
#  '(1966)',
#  '(2020)',
#  '(2002)',
#  '(1999)',
#  '(1990)',
#  '(1980)',
#  '(1975)',
#  '(2020)',
#  '(2019)',
#  '(2014)',
#  '(2002)',
#  '(2001)',
#  '(1998)',
#  '(1999)',
#  '(1997)',
#  '(1995)',
#  '(1991)',
#  '(1977)',
#  '(1962)',
#  '(1954)',
#  '(1946)',
#  '(2019)',
#  '(2014)',
#  '(2011)',
#  '(2006)',
#  '(2006)',
#  '(2002)',
#  '(2000)',
#  '(1998)',
#  '(1995)',
#  '(1994)',
#  '(1994)',
#  '(1991)',
#  '(1988)',
#  '(1988)',
#  '(1985)',
#  '(1968)',
#  '(1960)',
#  '(1942)',
#  '(1936)',
#  '(1931)',
#  '(2018)',
#  '(2017)',
#  '(2017)',
#  '(2016)',
#  '(2016)',
#  '(2018)',
#  '(2019)',
#  '(2018)',
#  '(I) (2017)',
#  '(2012)',
#  '(2012)',
#  '(2009)',
#  '(2007)',
#  '(2008)',
#  '(2006)',
#  '(2003)',
#  '(2000)',
#  '(1997)',
#  '(1984)',
#  '(1981)',
#  '(1980)',
#  '(1979)',
#  '(1979)',
# ...

# %%
Rate=[]
y1=soup.find_all('div', class_="inline-block ratings-imdb-rating")
y1
# Out:
# [<div class="inline-block ratings-imdb-rating" data-value="9.3" name="ir">
#  <span class="global-sprite rating-star imdb-rating"></span>
#  <strong>9.3</strong>
#  </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="9.2" name="ir">
#  <span class="global-sprite rating-star imdb-rating"></span>
#  <strong>9.2</strong>
#  </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="9" name="ir">
#  <span class="global-sprite rating-star imdb-rating"></span>
#  <strong>9.0</strong>
#  </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="9" name="ir">
#  <span class="global-sprite rating-star imdb-rating"></span>
#  <strong>9.0</strong>
#  </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="9" name="ir">
#  <span class="global-sprite rating-star imdb-rating"></span>
#  <strong>9.0</strong>
#  </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="8.9" name="ir">
# ...

# %%
for i in y1:
    Rate.append(i.text.replace("\n"," "))
Rate
# Out:
# ['  9.3 ',
#  '  9.2 ',
#  '  9.0 ',
#  '  9.0 ',
#  '  9.0 ',
#  '  8.9 ',
#  '  8.9 ',
#  '  8.9 ',
#  '  8.8 ',
#  '  8.8 ',
#  '  8.8 ',
#  '  8.8 ',
#  '  8.8 ',
#  '  8.7 ',
#  '  8.7 ',
#  '  8.7 ',
#  '  8.7 ',
#  '  8.7 ',
#  '  8.7 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.6 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.5 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
#  '  8.4 ',
# ...

# %%
rate= Rate[100:200]

# %%
len(year)
# Out:
# 100

# %%
#find length of all list

# %%
print(len(Rate),len(year),len(links))
# Out:
# 100 100 100

# %%
#create a dataframe and svae the result in the form of dataframe

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=links
jobs['year']=year
jobs['rate']=Rate

# %%
jobs
# Out:
#                                     title    year    rate
# 0                The Shawshank Redemption  (1994)    9.3
# 1                           The Godfather  (1972)    9.2
# 2                         The Dark Knight  (2008)    9.0
# 3                  The Godfather: Part II  (1974)    9.0
# 4                            12 Angry Men  (1957)    9.0
# ..                                    ...     ...     ...
# 95  Eternal Sunshine of the Spotless Mind  (2004)    8.3
# 96                                 Amélie  (2001)    8.3
# 97                                 Snatch  (2000)    8.3
# 98                    Requiem for a Dream  (2000)    8.3
# 99                        American Beauty  (1999)    8.3
#
# [100 rows x 3 columns]

# %%
#same the dataframe in the form of csv files

# %%
jobs.to_csv("q2.csv", index= False)

# %% [markdown]
# # question-3

# %% [markdown]
# # Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. Name, IMDB rating, Year of release) and save it in form of a CSV file.

# %%
#Fetch the main URL HTML code.

page3=requests.get("https://www.imdb.com/list/ls009997493/")

# %% [raw]
# # First let's write some code to grab the HTML from the web page, and look at how we can start parsing through it. The following code will send a GET request to the web page we want, and create a BeautifulSoup object with the HTML from that page:

# %%
#Feed that HTML to BeautifulSoup

page3.content
# Out:
# b'\n\n\n<!DOCTYPE html>\n<html\n    xmlns:og="http://ogp.me/ns#"\n    xmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n         \n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///list/ls009997493?src=mdot">\n\n\n\n        <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};</script>\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>\n        <title>IMDB Top 100 Hindi Movies - IMDb</title>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>\n<script>\n    if (typeof uet == \'function\') {\n      uet("be", "LoadTitle", {wb: 1});\n    }\n</script>\n<script>\n    
# ...

# %%
soup=BeautifulSoup(page3.content,'html.parser')

# %% [raw]
# #You can also provide different arguments to find_all, such as regular expressions or tag attributes to filter your search as specifically as you want.

# %%
heds = soup.find_all('h3',class_="lister-item-header")

# %%
links = []
for h in heds:
    a = h.find('a')
    links.append(a.text)

# %%
links
# Out:
# ['Rang De Basanti',
#  '3 Idiots',
#  'Taare Zameen Par',
#  'Dil Chahta Hai',
#  'Swades: We, the People',
#  'Lagaan: Once Upon a Time in India',
#  'Gangs of Wasseypur',
#  'Barfi!',
#  'Anand',
#  'Munna Bhai M.B.B.S.',
#  'A Wednesday',
#  'Andaz Apna Apna',
#  'Sholay',
#  'Bhaag Milkha Bhaag',
#  'Hera Pheri',
#  'Udaan',
#  'Kahaani',
#  'Black',
#  'Chak De! India',
#  'Khosla Ka Ghosla!',
#  'Jo Jeeta Wohi Sikandar',
#  'Zindagi Na Milegi Dobara',
#  'Paan Singh Tomar',
#  'Dilwale Dulhania Le Jayenge',
#  'Omkara',
#  'Lage Raho Munna Bhai',
#  'Iqbal',
#  'The Lunchbox',
#  'Black Friday',
#  'Company',
#  'Gol Maal',
#  'Dev.D',
#  'Jaane Bhi Do Yaaro',
#  'OMG: Oh My God!',
#  'Mughal-E-Azam',
#  'Gulaal',
#  'Dor',
#  'Jab We Met',
#  'Pyaasa',
#  'The Legend of Bhagat Singh',
#  'Masoom',
#  'Salaam Bombay!',
#  'Satya',
#  'Vicky Donor',
#  'Lakshya',
#  'Vaastav: The Reality',
#  'Kal Ho Naa Ho',
#  'Oye Lucky! Lucky Oye!',
#  'Sarfarosh',
#  'Gangaajal',
# ...

# %%
year=[]
y=soup.find_all('span', class_="lister-item-year text-muted unbold")
y[0:4]
# Out:
# [<span class="lister-item-year text-muted unbold">(2006)</span>,
#  <span class="lister-item-year text-muted unbold">(2009)</span>,
#  <span class="lister-item-year text-muted unbold">(2007)</span>,
#  <span class="lister-item-year text-muted unbold">(2001)</span>]

# %%
for i in y:
    year.append(i.text)
year
# Out:
# ['(2006)',
#  '(2009)',
#  '(2007)',
#  '(2001)',
#  '(2004)',
#  '(2001)',
#  '(2012)',
#  '(2012)',
#  '(1971)',
#  '(2003)',
#  '(2008)',
#  '(1994)',
#  '(1975)',
#  '(2013)',
#  '(2000)',
#  '(2010)',
#  '(2012)',
#  '(2005)',
#  '(2007)',
#  '(2006)',
#  '(1992)',
#  '(2011)',
#  '(2012)',
#  '(1995)',
#  '(2006)',
#  '(2006)',
#  '(2005)',
#  '(2013)',
#  '(2004)',
#  '(2002)',
#  '(1979)',
#  '(2009)',
#  '(1983)',
#  '(2012)',
#  '(1960)',
#  '(2009)',
#  '(2006)',
#  '(2007)',
#  '(1957)',
#  '(2002)',
#  '(1983)',
#  '(1988)',
#  '(1998)',
#  '(2012)',
#  '(2004)',
#  '(1999)',
#  '(2003)',
#  '(2008)',
#  '(1999)',
#  '(2003)',
#  '(1982)',
#  '(2013)',
#  '(2012)',
#  '(1975)',
#  '(2007)',
#  '(2003)',
#  '(2003)',
#  '(2008)',
#  '(1978)',
#  '(1976)',
#  '(1965)',
#  '(2013)',
#  '(1975)',
#  '(2013)',
#  '(1968)',
#  '(2008)',
#  '(2004)',
#  '(2013)',
#  '(1951)',
#  '(1955)',
#  '(1998)',
#  '(1998)',
#  '(1989)',
#  '(2008)',
#  '(2000)',
#  '(2003)',
# ...

# %%
print(len(rate),len(year),len(links))
# Out:
# 0 100 100

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=links
jobs['year']=year

# %%
jobs
# Out:
#                      title    year
# 0          Rang De Basanti  (2006)
# 1                 3 Idiots  (2009)
# 2         Taare Zameen Par  (2007)
# 3           Dil Chahta Hai  (2001)
# 4   Swades: We, the People  (2004)
# ..                     ...     ...
# 95             Wake Up Sid  (2009)
# 96                Rangeela  (1995)
# 97     Shatranj Ke Khilari  (1977)
# 98      Pyaar Ka Punchnama  (2011)
# 99           Ek Hasina Thi  (2004)
#
# [100 rows x 2 columns]

# %%
#same the dataframe in the form of csv files

# %%
jobs.to_csv("q3.csv", index= False)

# %% [markdown]
# # question=4 Write a python program to scrap book name, author name, genre and book review of any 5 books from ‘www.bookpage.com’

# %%
#Fetch the main URL HTML code.

page4=requests.get("https://bookpage.com/")
page44=requests.get("https://bookpage.com/reviews/25779-daniel-loedel-hades-argentina-fiction#.X_tTptgzbIU")

# %% [raw]
# #First let's write some code to grab the HTML from the web page, and look at how we can start parsing through it. The following code will send a GET request to the web page we want, and create a BeautifulSoup object with the HTML from that page:

# %%
#Fetch the main URL HTML code.
page4.content
# Out:
# b'<!DOCTYPE html>\n<html lang=\'en\' xmlns:fb=\'http://www.facebook.com/2008/fbml\' xmlns:og=\'http://opengraphprotocol.org/schema/\'>\n<head>\n<title>BookPage | Discover your next great book!</title>\n<meta name="description" content="Find expert book recommendations for the best books to read in all genres.">\n<meta name="keywords" content="books and literature, writing and writers">\n<link rel="canonical" href="https://bookpage.com/">\n<meta property="og:site_name" content="BookPage.com">\n<meta property="og:title" content="Discover your next great book!">\n<meta property="og:description" content="Find expert book recommendations for the best books to read in all genres.">\n<meta property="og:type" content="website">\n<meta property="og:url" content="https://bookpage.com/">\n<meta property="og:image" content="//www.bookpage.com/default_image.jpg">\n<meta name="twitter:card" content="summary">\n<meta name="twitter:site" content="@bookpage">\n<meta name="twitter:creator" content="@b
# ...

# %%
#Feed that HTML to BeautifulSoup

soup=BeautifulSoup(page4.content,'html.parser')

# %% [raw]
# #You can also provide different arguments to find_all, such as regular expressions or tag attributes to filter your search as specifically as you want.

# %%
title=[]
y=soup.find_all('h4', class_="italic")
y[0:4]
# Out:
# [<h4 class="italic">
#  <a href="/features/25862-snowy-days-childrens">Snowy days</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/features/25764-audio-january-2021-audio">Audio: January 2021</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/25814-sarah-moss-summerwater-fiction">Summerwater</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/25894-b-b-alston-amari-night-brothers-childrens">Amari and the Night Brothers</a>
#  </h4>]

# %%
for i in y:
    title.append(i.get_text().replace("\n"," "))
title
# Out:
# [' Snowy days ',
#  ' Audio: January 2021 ',
#  ' Summerwater ',
#  ' Amari and the Night Brothers ',
#  ' Winterkeep ',
#  ' The Crooked Path to Abolition ']

# %%
#title.remove(' 2021 preview: Most anticipated YA ')

# %%
review=[]
y1=soup.find_all('p', class_="sans bold")
y1[0:4]
# Out:
# [<p class="sans bold">
#  Feature by Alice Cary
#  </p>,
#  <p class="sans bold">
#  Feature by Anna Zeitlin
#  </p>,
#  <p class="sans bold">
#  Review by Thane Tierney
#  </p>,
#  <p class="sans bold">
#  Review by Alice Cary
#  </p>]

# %%
y1=soup.find('h4', class_="sans")

# %%
y1=soup.find('h4', class_="sans")

# %%
genre=[]
y11=soup.find_all('p', class_="genre-links hidden-phone")
y11[0:4]
# Out:
# [<p class="genre-links hidden-phone">
#  <a href="/search?book_genre=children_s">Children's</a>
#   /
#  <a href="/search?book_genre=children_s_picture_book">Children's Picture Book</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=audio">Audio</a>
#   /
#  <a href="/search?book_genre=poetry">Poetry</a>
#   /
#  <a href="/search?book_genre=fiction">Fiction</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=fiction">Fiction</a>
#   /
#  <a href="/search?book_genre=literary_fiction">Literary Fiction</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=children_s">Children's</a>
#   /
#  <a href="/search?book_genre=middle_grade">Middle Grade</a>
#  </p>]

# %%
for i in y11:
    genre.append(i.get_text().replace("\n"," "))
genre
# Out:
# [" Children's  /  Children's Picture Book ",
#  ' Audio  /  Poetry  /  Fiction ',
#  ' Fiction  /  Literary Fiction ',
#  " Children's  /  Middle Grade ",
#  ' YA  /  YA Fiction ',
#  ' Nonfiction  /  History  /  American History ']

# %%
print(len(title),len(genre))
# Out:
# 6 6

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['Book name']=title
jobs['Author and Review']=genre

# %%
jobs
# Out:
#                          Book name  \
# 0                      Snowy days
# 1             Audio: January 2021
# 2                     Summerwater
# 3    Amari and the Night Brothers
# 4                      Winterkeep
# 5   The Crooked Path to Abolition
#
#                                Author and Review
# 0        Children's  /  Children's Picture Book
# 1                  Audio  /  Poetry  /  Fiction
# 2                  Fiction  /  Literary Fiction
# 3                   Children's  /  Middle Grade
# 4                             YA  /  YA Fiction
# 5   Nonfiction  /  History  /  American History

# %%
#same the dataframe in the form of csv files

# %%
jobs.to_csv("q4.csv", index= False)

# %% [markdown]
# # question=5Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have to scrape:

# %% [raw]
# i) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
# ii) Top 10 ODI Batsmen in men along with the records of their team and rating.
# iii) Top 10 ODI bowlers along with the records of their team and rating.

# %% [raw]
# #First let's write some code to grab the HTML from the web page, and look at how we can start parsing through it. The following code will send a GET request to the web page we want, and create a BeautifulSoup object with the HTML from that page:

# %%
import selenium
import pandas as pd
from selenium import webdriver
import time

# %%
#lets first connevt to the web driver
driver=webdriver.Chrome(r"D:\flipnwork\chromedriver.exe ")

# %%
#Fetch the main URL HTML code.

url="https://www.icc-cricket.com/rankings/mens/team-rankings/odi"

# %%
driver.get(url)

# %% [raw]
# #You can also provide different arguments to find_all, such as regular expressions or tag attributes to filter your search as specifically as you want.

# %%
period=[]
period_name=[]
period=driver.find_elements_by_css_selector("#main-content > div > div.l-sticky-side-nav__content > div > div > section > div.rankings-block__container.full.rankings-table > table > tbody > tr > td.table-body__cell.rankings-table__team > span.u-hide-phablet")
period_name.append(list(map(lambda x:x.text,period)))

# %%
period_name
# Out:
# [['India',
#   'New Zealand',
#   'Australia',
#   'South Africa',
#   'Pakistan',
#   'Bangladesh',
#   'Sri Lanka',
#   'West Indies',
#   'Afghanistan',
#   'Ireland',
#   'Netherlands',
#   'Zimbabwe',
#   'Oman',
#   'Scotland',
#   'Nepal',
#   'UAE',
#   'Namibia',
#   'United States',
#   'Papua New Guinea']]

# %%
period_name1 = [val for sublist in period_name for val in sublist] 
period_name1
# Out:
# ['India',
#  'New Zealand',
#  'Australia',
#  'South Africa',
#  'Pakistan',
#  'Bangladesh',
#  'Sri Lanka',
#  'West Indies',
#  'Afghanistan',
#  'Ireland',
#  'Netherlands',
#  'Zimbabwe',
#  'Oman',
#  'Scotland',
#  'Nepal',
#  'UAE',
#  'Namibia',
#  'United States',
#  'Papua New Guinea']

# %%
len(period_name1)
# Out:
# 19

# %%
#main-content > div > div.l-sticky-side-nav__content > div > div > section > div.rankings-block__container.full.rankings-table > table > tbody > tr > td:nth-child(3)

# %%
match=[]
matches=[]
match=driver.find_elements_by_css_selector("#main-content > div > div.l-sticky-side-nav__content > div > div > section > div.rankings-block__container.full.rankings-table > table > tbody > tr > td:nth-child(3)")
matches.append(list(map(lambda x:x.text,match)))

# %%
matches
# Out:
# [['44',
#   '52',
#   '32',
#   '39',
#   '31',
#   '35',
#   '34',
#   '39',
#   '43',
#   '28',
#   '24',
#   '5',
#   '27',
#   '12',
#   '16',
#   '9',
#   '15',
#   '9',
#   '14',
#   '14']]

# %%
matches1 = [val for sublist in matches for val in sublist] 
matches1
# Out:
# ['44',
#  '52',
#  '32',
#  '39',
#  '31',
#  '35',
#  '34',
#  '39',
#  '43',
#  '28',
#  '24',
#  '5',
#  '27',
#  '12',
#  '16',
#  '9',
#  '15',
#  '9',
#  '14',
#  '14']

# %%
#main-content > div > div.l-sticky-side-nav__content > div > div > section > div.rankings-block__container.full.rankings-table > table > tbody > tr > td:nth-child(4)

# %%
points=[]
point=[]
point=driver.find_elements_by_css_selector("#main-content > div > div.l-sticky-side-nav__content > div > div > section > div.rankings-block__container.full.rankings-table > table > tbody > tr> td:nth-child(4)")
points.append(list(map(lambda x:x.text,point)))

# %%
points
# Out:
# [['5,405',
#   '6,102',
#   '3,716',
#   '4,344',
#   '3,345',
#   '3,490',
#   '2,989',
#   '3,297',
#   '3,285',
#   '1,549',
#   '1,256',
#   '222',
#   '1,121',
#   '479',
#   '419',
#   '161',
#   '259',
#   '152',
#   '185',
#   '0']]

# %%
points = [val for sublist in points for val in sublist] 
points
# Out:
# ['5,405',
#  '6,102',
#  '3,716',
#  '4,344',
#  '3,345',
#  '3,490',
#  '2,989',
#  '3,297',
#  '3,285',
#  '1,549',
#  '1,256',
#  '222',
#  '1,121',
#  '479',
#  '419',
#  '161',
#  '259',
#  '152',
#  '185',
#  '0']

# %%
rating=[]
rate=[]
rating=driver.find_elements_by_css_selector("#main-content > div > div.l-sticky-side-nav__content > div > div > section > div.rankings-block__container.full.rankings-table > table > tbody > tr > td.table-body__cell.u-text-right.rating")
rate.append(list(map(lambda x:x.text,rating)))

# %%
rate1 = [val for sublist in rate for val in sublist] 
rate1
# Out:
# ['117',
#  '116',
#  '111',
#  '108',
#  '100',
#  '88',
#  '85',
#  '76',
#  '55',
#  '52',
#  '44',
#  '42',
#  '40',
#  '26',
#  '18',
#  '17',
#  '17',
#  '13',
#  '0']

# %%
print(len(period_name1),len(matches1),len(points),len(rate1))
# Out:
# 19 20 20 19

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['team']=period_name1
jobs['match']=matches1[1:20]
jobs['points']=points[1:20]
jobs['rating']=rate1

# %%
jobs
# Out:
#                 team match points rating
# 0              India    52  6,102    117
# 1        New Zealand    32  3,716    116
# 2          Australia    39  4,344    111
# 3       South Africa    31  3,345    108
# 4           Pakistan    35  3,490    100
# 5         Bangladesh    34  2,989     88
# 6          Sri Lanka    39  3,297     85
# 7        West Indies    43  3,285     76
# 8        Afghanistan    28  1,549     55
# 9            Ireland    24  1,256     52
# 10       Netherlands     5    222     44
# 11          Zimbabwe    27  1,121     42
# 12              Oman    12    479     40
# 13          Scotland    16    419     26
# 14             Nepal     9    161     18
# 15               UAE    15    259     17
# 16           Namibia     9    152     17
# 17     United States    14    185     13
# 18  Papua New Guinea    14      0      0

# %%
new_row = pd.DataFrame({'team':'England','match':'44', 'points':5405,'rating':123 },index =[0]) 
# simply concatenate both dataframes 
df = pd.concat([new_row,jobs]).reset_index(drop = True) 
df.head(8)
# Out:
#            team match points rating
# 0       England    44   5405    123
# 1         India    52  6,102    117
# 2   New Zealand    32  3,716    116
# 3     Australia    39  4,344    111
# 4  South Africa    31  3,345    108
# 5      Pakistan    35  3,490    100
# 6    Bangladesh    34  2,989     88
# 7     Sri Lanka    39  3,297     85

# %%
#same the dataframe in the form of csv files

# %%
jobs.to_csv("q5-1.csv", index= False)

# %% [markdown]
# # Top 10 ODI Batsmen in men along with the records of their team and rating.

# %%
page0=requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/test")

# %%
page0.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Test Match Player Rankings International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council rankings for test match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council rankings for test match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Test Match Player Rankings International Cricket Council"/>\n<meta property="og:image" cont
# ...

# %%
soup=BeautifulSoup(page0.content,'html.parser')

# %%
heds = soup.find_all('td',class_="table-body__cell name")

# %%
links = []
for h in heds:
    a = h.find('a')
    links.append(a.text)

# %%
links
# Out:
# ['Steve Smith',
#  'Virat Kohli',
#  'Marnus Labuschagne',
#  'Babar Azam',
#  'Ben Stokes',
#  'Ajinkya Rahane',
#  'Cheteshwar Pujara',
#  'Henry Nicholls',
#  'David Warner',
#  'Stuart Broad',
#  'Neil Wagner',
#  'Tim Southee',
#  'Josh Hazlewood',
#  'Kagiso Rabada',
#  'James Anderson',
#  'Mitchell Starc',
#  'Ravichandran Ashwin',
#  'Jasprit Bumrah',
#  'Ravindra Jadeja',
#  'Jason Holder',
#  'Shakib Al Hasan',
#  'Kyle Jamieson',
#  'Mitchell Starc',
#  'Ravichandran Ashwin',
#  'Chris Woakes',
#  'Colin de Grandhomme',
#  'Pat Cummins',
#  'Steve Smith',
#  'Virat Kohli',
#  'Marnus Labuschagne',
#  'Babar Azam',
#  'Ben Stokes',
#  'Ajinkya Rahane',
#  'Cheteshwar Pujara',
#  'Henry Nicholls',
#  'David Warner',
#  'Stuart Broad',
#  'Neil Wagner',
#  'Tim Southee',
#  'Josh Hazlewood',
#  'Kagiso Rabada',
#  'James Anderson',
#  'Mitchell Starc',
#  'Ravichandran Ashwin',
#  'Jasprit Bumrah',
#  'Ravindra Jadeja',
#  'Jason Holder',
#  'Shakib Al Hasan',
# ...

# %%
rating=[]
titles11=soup.find_all('span', class_="table-body__logo-text")
titles11[0:4]
# Out:
# [<span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">PAK</span>]

# %%
for i in titles11:
    rating.append(i.get_text().replace("\n",""))
rating
# Out:
# ['AUS',
#  'IND',
#  'AUS',
#  'PAK',
#  'ENG',
#  'IND',
#  'IND',
#  'NZ',
#  'AUS',
#  'ENG',
#  'NZ',
#  'NZ',
#  'AUS',
#  'SA',
#  'ENG',
#  'AUS',
#  'IND',
#  'IND',
#  'IND',
#  'WI',
#  'BAN',
#  'NZ',
#  'AUS',
#  'IND',
#  'ENG',
#  'NZ',
#  'AUS',
#  'AUS',
#  'IND',
#  'AUS',
#  'PAK',
#  'ENG',
#  'IND',
#  'IND',
#  'NZ',
#  'AUS',
#  'ENG',
#  'NZ',
#  'NZ',
#  'AUS',
#  'SA',
#  'ENG',
#  'AUS',
#  'IND',
#  'IND',
#  'IND',
#  'WI',
#  'BAN',
#  'NZ',
#  'AUS',
#  'IND',
#  'ENG',
#  'NZ',
#  'AUS']

# %%
rate=[]
titles111=soup.find_all('td', class_="table-body__cell u-text-right rating")
titles111[0:4]
# Out:
# [<td class="table-body__cell u-text-right rating">900</td>,
#  <td class="table-body__cell u-text-right rating">870</td>,
#  <td class="table-body__cell u-text-right rating">866</td>,
#  <td class="table-body__cell u-text-right rating">781</td>]

# %%
for i in titles111:
    rate.append(i.get_text().replace("\n",""))
rate
# Out:
# ['900',
#  '870',
#  '866',
#  '781',
#  '760',
#  '756',
#  '753',
#  '747',
#  '745',
#  '845',
#  '825',
#  '811',
#  '805',
#  '786',
#  '781',
#  '774',
#  '768',
#  '765',
#  '428',
#  '423',
#  '366',
#  '293',
#  '291',
#  '287',
#  '269',
#  '258',
#  '250',
#  '900',
#  '870',
#  '866',
#  '781',
#  '760',
#  '756',
#  '753',
#  '747',
#  '745',
#  '845',
#  '825',
#  '811',
#  '805',
#  '786',
#  '781',
#  '774',
#  '768',
#  '765',
#  '428',
#  '423',
#  '366',
#  '293',
#  '291',
#  '287',
#  '269',
#  '258',
#  '250']

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['Player']=links[0:9]
jobs['Team']=rating[0:9]
jobs['rating']=rate[0:9]

# %%
new_row = pd.DataFrame({'Player':'Kane Williamson','Team':'NZ', 'rating':890},index =[0]) 
# simply concatenate both dataframes 
df = pd.concat([new_row,jobs]).reset_index(drop = True) 
df.head(8)
# Out:
#                Player Team rating
# 0     Kane Williamson   NZ    890
# 1         Steve Smith  AUS    900
# 2         Virat Kohli  IND    870
# 3  Marnus Labuschagne  AUS    866
# 4          Babar Azam  PAK    781
# 5          Ben Stokes  ENG    760
# 6      Ajinkya Rahane  IND    756
# 7   Cheteshwar Pujara  IND    753

# %%
df
# Out:
#                Player Team rating
# 0     Kane Williamson   NZ    890
# 1         Steve Smith  AUS    900
# 2         Virat Kohli  IND    870
# 3  Marnus Labuschagne  AUS    866
# 4          Babar Azam  PAK    781
# 5          Ben Stokes  ENG    760
# 6      Ajinkya Rahane  IND    756
# 7   Cheteshwar Pujara  IND    753
# 8      Henry Nicholls   NZ    747
# 9        David Warner  AUS    745

# %%
df.to_csv("q5-2.csv", index= False)

# %% [markdown]
# # Top 10 ODI Batsmen in men along with the records of their team and rating.

# %% [raw]
# #First let's write some code to grab the HTML from the web page, and look at how we can start parsing through it. The following code will send a GET request to the web page we want

# %%
page53=requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/test")

# %%
#Fetch the main URL HTML code.
page53.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Test Match Player Rankings International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council rankings for test match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council rankings for test match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Test Match Player Rankings International Cricket Council"/>\n<meta property="og:image" cont
# ...

# %%
soup=BeautifulSoup(page53.content,'html.parser')

# %% [raw]
# #You can also provide different arguments to find_all, such as regular expressions or tag attributes to filter your search as specifically as you want.

# %%
heds = soup.find_all('td',class_="table-body__cell name")

# %%
links = []
for h in heds:
    a = h.find('a')
    links.append(a.text)

# %%
links
# Out:
# ['Steve Smith',
#  'Virat Kohli',
#  'Marnus Labuschagne',
#  'Babar Azam',
#  'Ben Stokes',
#  'Ajinkya Rahane',
#  'Cheteshwar Pujara',
#  'Henry Nicholls',
#  'David Warner',
#  'Stuart Broad',
#  'Neil Wagner',
#  'Tim Southee',
#  'Josh Hazlewood',
#  'Kagiso Rabada',
#  'James Anderson',
#  'Mitchell Starc',
#  'Ravichandran Ashwin',
#  'Jasprit Bumrah',
#  'Ravindra Jadeja',
#  'Jason Holder',
#  'Shakib Al Hasan',
#  'Kyle Jamieson',
#  'Mitchell Starc',
#  'Ravichandran Ashwin',
#  'Chris Woakes',
#  'Colin de Grandhomme',
#  'Pat Cummins',
#  'Steve Smith',
#  'Virat Kohli',
#  'Marnus Labuschagne',
#  'Babar Azam',
#  'Ben Stokes',
#  'Ajinkya Rahane',
#  'Cheteshwar Pujara',
#  'Henry Nicholls',
#  'David Warner',
#  'Stuart Broad',
#  'Neil Wagner',
#  'Tim Southee',
#  'Josh Hazlewood',
#  'Kagiso Rabada',
#  'James Anderson',
#  'Mitchell Starc',
#  'Ravichandran Ashwin',
#  'Jasprit Bumrah',
#  'Ravindra Jadeja',
#  'Jason Holder',
#  'Shakib Al Hasan',
# ...

# %%
rating=[]
titles11=soup.find_all('span', class_="table-body__logo-text")
titles11[0:4]
# Out:
# [<span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">PAK</span>]

# %%
for i in titles11:
    rating.append(i.get_text().replace("\n",""))
rating[0:10]

# %%
rate=[]
titles111=soup.find_all('td', class_="table-body__cell u-text-right rating")
titles111[0:4]
# Out:
# [<td class="table-body__cell u-text-right rating">900</td>,
#  <td class="table-body__cell u-text-right rating">870</td>,
#  <td class="table-body__cell u-text-right rating">866</td>,
#  <td class="table-body__cell u-text-right rating">781</td>]

# %%
for i in titles111:
    rate.append(i.get_text().replace("\n",""))
rate
# Out:
# ['900',
#  '870',
#  '866',
#  '781',
#  '760',
#  '756',
#  '753',
#  '747',
#  '745',
#  '845',
#  '825',
#  '811',
#  '805',
#  '786',
#  '781',
#  '774',
#  '768',
#  '765',
#  '428',
#  '423',
#  '366',
#  '293',
#  '291',
#  '287',
#  '269',
#  '258',
#  '250',
#  '900',
#  '870',
#  '866',
#  '781',
#  '760',
#  '756',
#  '753',
#  '747',
#  '745',
#  '845',
#  '825',
#  '811',
#  '805',
#  '786',
#  '781',
#  '774',
#  '768',
#  '765',
#  '428',
#  '423',
#  '366',
#  '293',
#  '291',
#  '287',
#  '269',
#  '258',
#  '250']

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['Player']=links[9:20]
jobs['Team']=rating[9:20]
jobs['rating']=rate[9:20]

# %%
new_row = pd.DataFrame({'Player':'Meg Lanning','Team':'AUS', 'rating':749, },index =[0]) 
# simply concatenate both dataframes 
df = pd.concat([new_row,jobs]).reset_index(drop = True) 
df.head(8)
# Out:
#            Player Team rating
# 0     Meg Lanning  AUS    749
# 1    Stuart Broad  ENG    845
# 2     Neil Wagner   NZ    825
# 3     Tim Southee   NZ    811
# 4  Josh Hazlewood  AUS    805
# 5   Kagiso Rabada   SA    786
# 6  James Anderson  ENG    781
# 7  Mitchell Starc  AUS    774

# %%
jobs
# Out:
#                  Player Team rating
# 0          Stuart Broad  ENG    845
# 1           Neil Wagner   NZ    825
# 2           Tim Southee   NZ    811
# 3        Josh Hazlewood  AUS    805
# 4         Kagiso Rabada   SA    786
# 5        James Anderson  ENG    781
# 6        Mitchell Starc  AUS    774
# 7   Ravichandran Ashwin  IND    768
# 8        Jasprit Bumrah  IND    765
# 9       Ravindra Jadeja  IND    428
# 10         Jason Holder   WI    423

# %%
#same the dataframe in the form of csv files

# %%
jobs.to_csv("q5-3.csv", index= False)

# %% [markdown]
# # 6. Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have to scrape:

# %% [raw]
# #First let's write some code to grab the HTML from the web page, and look at how we can start parsing through it. The following code will send a GET request to the web page we want.

# %%
#Fetch the main URL HTML code.

page61=requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")

# %%
page61.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta property="og:image" content="https://w
# ...

# %%
soup=BeautifulSoup(page61.content,'html.parser')

# %% [raw]
# #You can also provide different arguments to find_all, such as regular expressions or tag attributes to filter your search as specifically as you want.

# %%
team=[]
titles11=soup.find_all('span', class_="u-hide-phablet")
titles11[0:4]
# Out:
# [<span class="u-hide-phablet">Australia</span>,
#  <span class="u-hide-phablet">India</span>,
#  <span class="u-hide-phablet">England</span>,
#  <span class="u-hide-phablet">South Africa</span>]

# %%
for i in titles11:
    team.append(i.get_text().replace("\n",""))
team
# Out:
# ['Australia',
#  'India',
#  'England',
#  'South Africa',
#  'New Zealand',
#  'West Indies',
#  'Pakistan',
#  'Bangladesh',
#  'Sri Lanka',
#  'Ireland',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
rating=[]
titles11=soup.find_all('td', class_="table-body__cell u-center-text")
titles11[0:4]
# Out:
# [<td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,812</td>,
#  <td class="table-body__cell u-center-text">14</td>,
#  <td class="table-body__cell u-center-text">1,670</td>]

# %%
for i in titles11:
    rating.append(i.get_text().replace("\n",""))
rating
# Out:
# ['15',
#  '1,812',
#  '14',
#  '1,670',
#  '16',
#  '1,713',
#  '15',
#  '1,384',
#  '12',
#  '1,025',
#  '12',
#  '927',
#  '5',
#  '306',
#  '11',
#  '519',
#  '2',
#  '25']

# %%
matches=[]
point=[]

# %%
for i in rating[0:len(rating):2]:
    matches.append(i)
print(matches)
# Out:
# ['15', '14', '16', '15', '12', '12', '5', '11', '2']

# %%
for i in rating[1:len(rating):2]:
    point.append(i)
print(point)
# Out:
# ['1,812', '1,670', '1,713', '1,384', '1,025', '927', '306', '519', '25']

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['Player']=team[1:9]
jobs['Team']=matches[0:8]
jobs['rating']=point[0:8]

# %%
new_row = pd.DataFrame({'Player':'Australia', 'Team':15, 'rating':2436, },index =[0]) 
# simply concatenate both dataframes 
df = pd.concat([new_row, df]).reset_index(drop = True) 
df.head(5)
# Out:
#          Player Team rating
# 0     Australia   15   2436
# 1   Meg Lanning  AUS    749
# 2  Stuart Broad  ENG    845
# 3   Neil Wagner   NZ    825
# 4   Tim Southee   NZ    811

# %%
df
# Out:
#                  Player Team rating
# 0             Australia   15   2436
# 1           Meg Lanning  AUS    749
# 2          Stuart Broad  ENG    845
# 3           Neil Wagner   NZ    825
# 4           Tim Southee   NZ    811
# 5        Josh Hazlewood  AUS    805
# 6         Kagiso Rabada   SA    786
# 7        James Anderson  ENG    781
# 8        Mitchell Starc  AUS    774
# 9   Ravichandran Ashwin  IND    768
# 10       Jasprit Bumrah  IND    765
# 11      Ravindra Jadeja  IND    428
# 12         Jason Holder   WI    423

# %%
df.to_csv("q6-2.csv", index= False)

# %% [markdown]
# # question-7Write a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in. The scraped data should include Product Name, Price, Image URL and Average Rating.

# %% [raw]
# #First let's write some code to grab the HTML from the web page, and look at how we can start parsing through it. The following code will send a GET request to the web page we want,

# %%
#import all the library
import selenium
import pandas as pd
from selenium import webdriver
import time

# %%
#create webdriver object
driver=webdriver.Chrome(r"D:\flipnwork\chromedriver.exe")

# %%
#get link
url="https://www.amazon.in/s?k=mobile+under+20000&ref=nb_sb_noss_1"

# %%
driver.get(url)

# %% [markdown]
# #You can also provide different arguments to find_all, such as regular expressions or tag attributes to filter your search as specifically as you want.

# %%
# enter number of pages to search how many pages information to insert

n=int(input("Enter number of pages to be retained"))
# Out:
# Enter number of pages to be retained2

# %%
# creating the list
image_url=[]
Average_rating=[]
rate=[]
images=[]
rating=[]
pricerange=[]
price=[]
Product_name=[]
product=[]
imagesColab=[]

# %%
# i had created forloop 
for i in range(n):
    try:
        driver.find_element_by_css_selector("#search > div.s-desktop-width-max.s-desktop-content.sg-row > div.sg-col-16-of-20.sg-col.sg-col-8-of-12.sg-col-12-of-16 > div > span:nth-child(4) > div.s-main-slot.s-result-list.s-search-results.sg-row > div:nth-child(5) > div")
        driver.execute_script('document.querySelector("#search > div.s-desktop-width-max.s-desktop-content.sg-row > div.sg-col-16-of-20.sg-col.sg-col-8-of-12.sg-col-12-of-16 > div > span:nth-child(4) > div.s-main-slot.s-result-list.s-search-results.sg-row > div:nth-child(5)").innerHTML=""')
    except:
        ""
    product=driver.find_elements_by_css_selector("#search > div.s-desktop-width-max.s-desktop-content.sg-row > div.sg-col-16-of-20.sg-col.sg-col-8-of-12.sg-col-12-of-16 > div > span:nth-child(4) > div.s-main-slot.s-result-list.s-search-results.sg-row > div > div > span > div > div > div:nth-child(2) > div.sg-col-4-of-12.sg-col-8-of-16.sg-col-12-of-20.sg-col > div > div:nth-child(1) > div > div > div:nth-child(1) > h2 > a > span")
    Product_name.append(list(map(lambda x:x.text, product)))
    pricerange=driver.find_elements_by_css_selector("#search > div.s-desktop-width-max.s-desktop-content.sg-row > div.sg-col-16-of-20.sg-col.sg-col-8-of-12.sg-col-12-of-16 > div > span:nth-child(4) > div.s-main-slot.s-result-list.s-search-results.sg-row > div > div > span > div > div > div:nth-child(2) > div.sg-col-4-of-12.sg-col-8-of-16.sg-col-12-of-20.sg-col > div > div:nth-child(2) > div.sg-col-4-of-12.sg-col-4-of-16.sg-col.sg-col-4-of-20 > div > div.a-section.a-spacing-none.a-spacing-top-small > div.a-row.a-size-base.a-color-base > div > div > a > span:nth-child(1) > span:nth-child(2) > span.a-price-whole")
    price.append(list(map(lambda x:x.text,pricerange)))
    rate=driver.find_elements_by_css_selector("#search > div.s-desktop-width-max.s-desktop-content.sg-row > div.sg-col-16-of-20.sg-col.sg-col-8-of-12.sg-col-12-of-16 > div > span:nth-child(4) > div.s-main-slot.s-result-list.s-search-results.sg-row > div > div > span > div > div > div:nth-child(2) > div.sg-col-4-of-12.sg-col-8-of-16.sg-col-12-of-20.sg-col > div > div:nth-child(1) > div > div > div.a-section.a-spacing-none.a-spacing-top-micro > div > span:nth-child(2) > a > span")
    rating.append(list(map(lambda x:x.text,rate)))
    images=driver.find_elements_by_css_selector("#search > div.s-desktop-width-max.s-desktop-content.sg-row > div.sg-col-16-of-20.sg-col.sg-col-8-of-12.sg-col-12-of-16 > div > span:nth-child(4) > div.s-main-slot.s-result-list.s-search-results.sg-row > div > div > span > div > div > div:nth-child(2) > div.sg-col-4-of-12.sg-col-4-of-16.sg-col.sg-col-4-of-20 > div > div > span > a > div > img")
    imagesColab.append(list(map(lambda x:x.get_attribute("src"),images)))
    driver.find_element_by_css_selector("#search > div.s-desktop-width-max.s-desktop-content.sg-row > div.sg-col-16-of-20.sg-col.sg-col-8-of-12.sg-col-12-of-16 > div > span:nth-child(4) > div.s-main-slot.s-result-list.s-search-results.sg-row > div > span > div > div > ul > li.a-last").click()
    time.sleep(10)

# %%
print(len(price[0]))
print(len(Product_name[0]))
print(len(rating[0]))
print(len(imagesColab[0]))
# Out:
# 15
# 15
# 15
# 15

# %%
Product_name
# Out:
# [['Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)',
#   'Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB Storage)',
#   'Samsung Galaxy M01 Core (Black, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#   'Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64GB Storage)',
#   'Samsung Galaxy M01 (Blue, 3GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#   'Redmi 9A (Nature Green, 2GB Ram, 32GB Storage)',
#   'Redmi Note 9 Pro (Interstellar Black, 4GB RAM, 64GB Storage)- Latest 8nm Snapdragon 720G & Alexa Hands-Free | Upto 6 Months No Cost EMI',
#   'Redmi 9A (Midnight Black, 3GB Ram, 32GB Storage)',
#   'Samsung Galaxy M31 Prime Edition (Space Black, 6GB RAM, 128GB Storage)',
#   'Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storage) - 48MP Quad Camera & Full HD+ Display',
#   'Redmi 8A Dual (Sky White, 3GB RAM, 64GB Storage) – Dual Cameras & 5,000 mAH Battery',
#   'Panasonic Eluga i7 (2GB RAM, 16GB Storage, Finger Print Sensor, 4000mAh Battery) (Black)',
# ...

# %%
#convert 2d in to 1D

# %%
Product_name
flatten_matrix1 = [val for sublist in Product_name for val in sublist] 
flatten_matrix1
# Out:
# ['Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)',
#  'Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB Storage)',
#  'Samsung Galaxy M01 Core (Black, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64GB Storage)',
#  'Samsung Galaxy M01 (Blue, 3GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Redmi 9A (Nature Green, 2GB Ram, 32GB Storage)',
#  'Redmi Note 9 Pro (Interstellar Black, 4GB RAM, 64GB Storage)- Latest 8nm Snapdragon 720G & Alexa Hands-Free | Upto 6 Months No Cost EMI',
#  'Redmi 9A (Midnight Black, 3GB Ram, 32GB Storage)',
#  'Samsung Galaxy M31 Prime Edition (Space Black, 6GB RAM, 128GB Storage)',
#  'Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storage) - 48MP Quad Camera & Full HD+ Display',
#  'Redmi 8A Dual (Sky White, 3GB RAM, 64GB Storage) – Dual Cameras & 5,000 mAH Battery',
#  'Panasonic Eluga i7 (2GB RAM, 16GB Storage, Finger Print Sensor, 4000mAh Battery) (Black)',
# ...

# %%
price
flatten_matrix2 = [val for sublist in price for val in sublist] 
flatten_matrix2
# Out:
# ['8,999',
#  '16,499',
#  '5,999',
#  '13,999',
#  '7,499',
#  '6,999',
#  '12,999',
#  '7,499',
#  '16,499',
#  '11,999',
#  '7,999',
#  '5,000',
#  '6,999',
#  '5,999',
#  '7,999',
#  '19,499',
#  '4,999',
#  '13,990',
#  '12,999',
#  '13,999',
#  '16,499',
#  '8,990',
#  '7,999',
#  '4,999',
#  '9,999',
#  '9,999',
#  '17,990',
#  '9,999',
#  '8,999',
#  '15,999']

# %%
rating
flatten_matrix3 = [val for sublist in rating for val in sublist] 
flatten_matrix3
# Out:
# ['9,155',
#  '125,495',
#  '7,752',
#  '84,579',
#  '8,814',
#  '11,339',
#  '28,810',
#  '11,339',
#  '125,495',
#  '24,247',
#  '33,286',
#  '933',
#  '11,339',
#  '7,752',
#  '33,286',
#  '38,788',
#  '7,752',
#  '1,780',
#  '28,810',
#  '84,579',
#  '125,495',
#  '3,755',
#  '33,286',
#  '7,752',
#  '9,155',
#  '11,947',
#  '56',
#  '11,947',
#  '1,036',
#  '84,579']

# %%
print(len(flatten_matrix1),len(flatten_matrix2),len(flatten_matrix3))
# Out:
# 30 30 30

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['Product_name']=flatten_matrix1[0:10]
jobs['price']=flatten_matrix2[0:10]
jobs['rating']=flatten_matrix3[0:10]

# %%
jobs.head(10)
# Out:
#                                         Product_name   price   rating
# 0          Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)   8,999    9,155
# 1  Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB...  16,499  125,495
# 2  Samsung Galaxy M01 Core (Black, 2GB RAM, 32GB ...   5,999    7,752
# 3  Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64...  13,999   84,579
# 4  Samsung Galaxy M01 (Blue, 3GB RAM, 32GB Storag...   7,499    8,814
# 5     Redmi 9A (Nature Green, 2GB Ram, 32GB Storage)   6,999   11,339
# 6  Redmi Note 9 Pro (Interstellar Black, 4GB RAM,...  12,999   28,810
# 7   Redmi 9A (Midnight Black, 3GB Ram, 32GB Storage)   7,499   11,339
# 8  Samsung Galaxy M31 Prime Edition (Space Black,...  16,499  125,495
# 9  Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storag...  11,999   24,247

# %%
#same the dataframe in the form of csv files

# %%
jobs.to_csv("q7maim.csv", index= False)

# %%
val=driver.find_elements_by_css_selector("#search > div.s-desktop-width-max.s-desktop-content.sg-row > div.sg-col-16-of-20.sg-col.sg-col-8-of-12.sg-col-12-of-16 > div > span:nth-child(4) > div.s-main-slot.s-result-list.s-search-results.sg-row > div > div > span > div > div > div:nth-child(2) > div.sg-col-4-of-12.sg-col-4-of-16.sg-col.sg-col-4-of-20 > div > div > span > a > div > img")

# %%
val=list(map(lambda x:x.get_attribute("src"),val))

# %%
val
# Out:
# ['https://m.media-amazon.com/images/I/71hqi389rcL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71UZfRHB7UL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/61CnyJ-IbML._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/51FnmxwFHDL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/61GAFSlKhDL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/719lhUzicYL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/714qRVfu2vL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/81EjHa-dSJL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/51-T19jXchL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71-nSoWl8iL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/714qRVfu2vL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/81Ox29uGzNL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/81pzsRpE5GL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/51EnyMldjGL._AC_UY218_.jpg',
# ...

# %% [markdown]
# # question-8 Write a python program to extract information about the local weather from the National Weather Service website of USA, https://www.weather.gov/ for the city, San Francisco. You need to extract data about 7 day extended forecast display for the city. The data should include period, short description, temperature and description.

# %% [raw]
# #First let's write some code to grab the HTML from the web page, and look at how we can start parsing through it. The following code will send a GET request to the web page we want.

# %%
#Fetch the main URL HTML code.

url="https://forecast.weather.gov/MapClick.php?lat=37.77493000000004&lon=-122.41941999999995#.YAPdzOgzbIV"

# %%
driver.get(url)

# %% [raw]
# #You can also provide different arguments to find_all, such as regular expressions or tag attributes to filter your search as specifically as you want.

# %%
period=[]
period_name=[]
period=driver.find_elements_by_xpath("//p[@class='period-name']")
period_name.append(list(map(lambda x:x.text.replace("\n"," "),period)))

# %%
period_name
# Out:
# [['NOW until 3:00pm Mon',
#   'Tonight',
#   'M.L.King Day',
#   'Monday Night',
#   'Tuesday',
#   'Tuesday Night',
#   'Wednesday',
#   'Wednesday Night',
#   'Thursday']]

# %%
#convert 2d in to 1D

# %%
period_name1 = [val for sublist in period_name for val in sublist] 
period_name1
# Out:
# ['NOW until 3:00pm Mon',
#  'Tonight',
#  'M.L.King Day',
#  'Monday Night',
#  'Tuesday',
#  'Tuesday Night',
#  'Wednesday',
#  'Wednesday Night',
#  'Thursday']

# %%
description=[]
des=[]
des=driver.find_elements_by_xpath("//p[@class='short-desc']")
description.append(list(map(lambda x:x.text.replace("\n"," "),des)))

# %%
description
# Out:
# [['High Surf Advisory',
#   'Partly Cloudy',
#   'Sunny',
#   'Clear then Mostly Clear and Breezy',
#   'Sunny and Breezy then Sunny',
#   'Clear',
#   'Sunny',
#   'Mostly Clear',
#   'Mostly Sunny']]

# %%
#convert 2d in to 1D

# %%
description1 = [val for sublist in description for val in sublist] 
description1
# Out:
# ['High Surf Advisory',
#  'Partly Cloudy',
#  'Sunny',
#  'Clear then Mostly Clear and Breezy',
#  'Sunny and Breezy then Sunny',
#  'Clear',
#  'Sunny',
#  'Mostly Clear',
#  'Mostly Sunny']

# %%
temperature=[]
temp=[]
temp=driver.find_elements_by_xpath("//p[@class='temp temp-low']")
temperature.append(list(map(lambda x:x.text.replace("\n"," "),temp)))

# %%
temperature
# Out:
# [['Low: 50 °F', 'Low: 51 °F', 'Low: 46 °F', 'Low: 45 °F']]

# %%
#convert 2d in to 1D

# %%
temperature1 = [val for sublist in temperature for val in sublist] 
temperature1
# Out:
# ['Low: 50 °F', 'Low: 51 °F', 'Low: 46 °F', 'Low: 45 °F']

# %%
temperatureh=[]
temph=[]
temph=driver.find_elements_by_xpath("//p[@class='temp temp-high']")
temperatureh.append(list(map(lambda x:x.text.replace("\n"," "),temph)))

# %%
temperatureh
# Out:
# [['High: 71 °F', 'High: 68 °F', 'High: 63 °F', 'High: 60 °F']]

# %%
temperatureh1 = [val for sublist in temperatureh for val in sublist] 
temperatureh1
# Out:
# ['High: 71 °F', 'High: 68 °F', 'High: 63 °F', 'High: 60 °F']

# %%
des11=[]
des111=[]
des11=driver.find_elements_by_xpath("//div[@class='col-sm-10 forecast-text']")
des111.append(list(map(lambda x:x.text.replace("\n"," "),des11)))

# %%
des111
# Out:
# [['Partly cloudy, with a low around 50. Calm wind becoming west around 5 mph.',
#   'Sunny, with a high near 71. North wind 7 to 14 mph, with gusts as high as 18 mph.',
#   'Mostly clear, with a low around 51. Breezy, with a north wind 16 to 25 mph, with gusts as high as 44 mph.',
#   'Sunny, with a high near 68. Breezy, with a north northeast wind 20 to 24 mph, with gusts as high as 41 mph.',
#   'Clear, with a low around 46. North northeast wind 3 to 6 mph. Winds could gust as high as 30 mph.',
#   'Sunny, with a high near 63.',
#   'Mostly clear, with a low around 45.',
#   'Mostly sunny, with a high near 60.',
#   'Partly cloudy, with a low around 46.',
#   'A slight chance of rain. Mostly sunny, with a high near 57.',
#   'A slight chance of rain. Partly cloudy, with a low around 44.',
#   'Sunny, with a high near 58.',
#   'A slight chance of rain. Mostly clear, with a low around 44.',
#   'A chance of rain. Partly sunny, with a high near 56.']]

# %%
#convert 2d in to 1D

# %%
des1111 = [val for sublist in des111 for val in sublist] 
des1111
# Out:
# ['Partly cloudy, with a low around 50. Calm wind becoming west around 5 mph.',
#  'Sunny, with a high near 71. North wind 7 to 14 mph, with gusts as high as 18 mph.',
#  'Mostly clear, with a low around 51. Breezy, with a north wind 16 to 25 mph, with gusts as high as 44 mph.',
#  'Sunny, with a high near 68. Breezy, with a north northeast wind 20 to 24 mph, with gusts as high as 41 mph.',
#  'Clear, with a low around 46. North northeast wind 3 to 6 mph. Winds could gust as high as 30 mph.',
#  'Sunny, with a high near 63.',
#  'Mostly clear, with a low around 45.',
#  'Mostly sunny, with a high near 60.',
#  'Partly cloudy, with a low around 46.',
#  'A slight chance of rain. Mostly sunny, with a high near 57.',
#  'A slight chance of rain. Partly cloudy, with a low around 44.',
#  'Sunny, with a high near 58.',
#  'A slight chance of rain. Mostly clear, with a low around 44.',
#  'A chance of rain. Partly sunny, with a high near 56.']

# %%
print(len(period_name1),len(description1),len(temperature1),len(des1111))
# Out:
# 9 9 4 14

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['Period']=period_name1
jobs['temperature']=description1

# %%
jobs
# Out:
#                  Period                         temperature
# 0  NOW until 3:00pm Mon                  High Surf Advisory
# 1               Tonight                       Partly Cloudy
# 2          M.L.King Day                               Sunny
# 3          Monday Night  Clear then Mostly Clear and Breezy
# 4               Tuesday         Sunny and Breezy then Sunny
# 5         Tuesday Night                               Clear
# 6             Wednesday                               Sunny
# 7       Wednesday Night                        Mostly Clear
# 8              Thursday                        Mostly Sunny

# %%
#same the dataframe in the form of csv files

# %%
jobs.to_csv("q8.csv", index= False)

# %% [markdown]
# # question-9Write a python program to scrape ‘software developer’ job listings from ‘Monster.com’. It should include all the jobs listed for the next 5 pages

# %% [raw]
# #First let's write some code to grab the HTML from the web page, and look at how we can start parsing through it. The following code will send a GET request to the web page we want.

# %%
#Fetch the main URL HTML code.

url="https://www.monsterindia.com/srp/results?query=Software%20Developer&searchId=5b9ec73d-417d-4384-98c5-64acd8d3b7d1"

# %%
driver.get(url)

# %% [raw]
# #You can also provide different arguments to find_all, such as regular expressions or tag attributes to filter your search as specifically as you want.

# %%
n=int(input("Enter number of pages to be retained"))
# Out:
# Enter number of pages to be retained5

# %%
job_titles=[]
company_list=[]
location_list=[]
experience=[]
titles_tags=[]
company_tag=[]
location_tag=[]
ratess=[]
rates=[]
pack=[]
pack2=[]
desc=[]
desc1=[]
skill=[]
skill1=[]

# %%
for i in range(n):
    titles_tags=driver.find_elements_by_xpath("//h3[@class='medium']")
    job_titles.append(list(map(lambda x:x.text,titles_tags)))
    company_tag=driver.find_elements_by_xpath("//span[@class='company-name']")
    company_list.append(list(map(lambda x:x.text,company_tag)))
    location_tag=driver.find_elements_by_css_selector("#srp-right-part > div > div.srp-left > div:nth-child(1) > div:nth-child(2) > div > div > div > div.card-body.card-body-apply.pd10 > div > div > div > div.col-xxs-12.col-sm-5.text-ellipsis > span")
    location_list.append(list(map(lambda x:x.text,location_tag)))
    ratess=driver.find_elements_by_css_selector("#srp-right-part > div > div.srp-left > div:nth-child(1) > div:nth-child(2) > div > div> div > div.card-body.card-body-apply.pd10 > div > div > div > div.exp.col-xxs-12.col-sm-3.text-ellipsis > span > small")
    rates.append(list(map(lambda x:x.text,ratess)))
    pack=driver.find_elements_by_css_selector("#srp-right-part > div > div.srp-left > div:nth-child(1) > div:nth-child(2) > div > div > div > div.card-body.card-body-apply.pd10 > div > div > div > div.package.col-xxs-12.col-sm-4.text-ellipsis > span")
    pack2.append(list(map(lambda x:x.text,pack)))
    desc=driver.find_elements_by_css_selector("#srp-right-part > div > div.srp-left > div:nth-child(1) > div:nth-child(2) > div > div > div > div.card-body.card-body-apply.pd10 > div > p.job-descrip")
    desc1.append(list(map(lambda x:x.text,desc)))
    skill=driver.find_elements_by_css_selector("#srp-right-part > div > div.srp-left > div:nth-child(1) > div:nth-child(2) > div > div> div > div.card-body.card-body-apply.pd10 > div > p.descrip-skills")
    skill1.append(list(map(lambda x:x.text,pack)))
    driver.find_element_by_css_selector("#srp-right-part > div > div.srp-left > div:nth-child(1) > div:nth-child(3) > div > div > a:nth-child(2) > button").click()
    time.sleep(10)

# %%
job_titles
# Out:
# [['Systems Admin',
#   'Hiring For SQL Server Developer',
#   'Mean Stack Developer',
#   'PHP Developer',
#   'Sap BW&Hana&ABAP',
#   'Software Developer - .Net in MNC Company',
#   'Backend Streaming Engineer Job',
#   'AccionLabs Seeking SalesForce Lightning Developer with 5+ years of expertise',
#   'Java Developer For MNC Company',
#   'Dotnet Developer or .Net developer',
#   'Software Engineer (C#)',
#   'Web developer',
#   'Php developer"',
#   'SAP PPDS Consultant',
#   'Android Developer',
#   'iOS developer',
#   'Java Microservices Jr. Consultant',
#   'Java Testing | SDET',
#   'iOS developer',
#   'Reuired urgently python Developer for Andheri location',
#   'Java Developer',
#   'Looking For Core Java Freshers',
#   'Duck Creek policy',
#   'Big Data Hadoop',
#   'Full Stack Developer'],
#  ['iOS developer',
#   'Reuired urgently python Developer for Andheri location',
#   'Java Developer',
#   'Looking For Core Java Freshers',
#   'Duck Creek policy',
# ...

# %%
company_list
# Out:
# [['URS Systems Private Limited',
#   'Yashodha S M (Proprietor Of Co Inter Technology)',
#   'Delivery Centric Technology Services Private Limited',
#   'Company Name Confidential',
#   'Macropace Technologies',
#   'Sharp Point HR Consulting',
#   'C P Careers Private Limited',
#   'Accion Labs India Private Limited',
#   'Infomedia Solutions And Consultant',
#   'Klaus It Solutions Private Limited',
#   'Kameda Infologics Private Limited',
#   'Infomedia Solutions And Consultant',
#   'Saar IT Resources Private Limited',
#   'Numeric Technologies Incorporation',
#   'Infopro solutions pvt ltd',
#   'Infopro solutions pvt ltd',
#   'URS Systems Private Limited',
#   'URS Systems Private Limited',
#   'Sanda Office Management Services Private Limited',
#   'Company Name Confidential',
#   'Infopro solutions pvt ltd',
#   'Yashodha S M (Proprietor Of Co Inter Technology)',
#   'Saransh Software Solutions Private Limited',
#   'Corascent',
#   'Intellect Design Arena Limited'],
# ...

# %%
location_list
# Out:
# [['Bengaluru / Bangalore',
#   'Delhi',
#   'Bengaluru / Bangalore',
#   'Indore',
#   'Bengaluru / Bangalore',
#   'Delhi',
#   'Bengaluru / Bangalore, Kolkata',
#   'Bengaluru / Bangalore',
#   'Pune',
#   'Bengaluru / Bangalore',
#   'Delhi, Thiruvananthapuram / Trivandrum',
#   'Pune',
#   'Mumbai City',
#   'Hyderabad / Secunderabad',
#   'Thiruvananthapuram / Trivandrum',
#   'Thiruvananthapuram / Trivandrum',
#   'Bengaluru / Bangalore',
#   'Bengaluru / Bangalore',
#   'Mumbai, Mumbai City, Navi Mumbai',
#   'Mumbai, Mumbai City, Navi Mumbai, Thane',
#   'Bengaluru / Bangalore',
#   'Erode',
#   'Bengaluru / Bangalore, Chennai',
#   'Bengaluru / Bangalore, Pune',
#   'Chennai, Hyderabad / Secunderabad'],
#  ['Mumbai, Mumbai City, Navi Mumbai',
#   'Mumbai, Mumbai City, Navi Mumbai, Thane',
#   'Bengaluru / Bangalore',
#   'Erode',
#   'Bengaluru / Bangalore, Chennai',
#   'Bengaluru / Bangalore, Pune',
#   'Chennai, Hyderabad / Secunderabad',
#   'Kolkata',
# ...

# %%
#convert 2d in to 1D

# %%
job_titles
flatten_matrix1 = [val for sublist in job_titles for val in sublist] 
flatten_matrix1
# Out:
# ['Systems Admin',
#  'Hiring For SQL Server Developer',
#  'Mean Stack Developer',
#  'PHP Developer',
#  'Sap BW&Hana&ABAP',
#  'Software Developer - .Net in MNC Company',
#  'Backend Streaming Engineer Job',
#  'AccionLabs Seeking SalesForce Lightning Developer with 5+ years of expertise',
#  'Java Developer For MNC Company',
#  'Dotnet Developer or .Net developer',
#  'Software Engineer (C#)',
#  'Web developer',
#  'Php developer"',
#  'SAP PPDS Consultant',
#  'Android Developer',
#  'iOS developer',
#  'Java Microservices Jr. Consultant',
#  'Java Testing | SDET',
#  'iOS developer',
#  'Reuired urgently python Developer for Andheri location',
#  'Java Developer',
#  'Looking For Core Java Freshers',
#  'Duck Creek policy',
#  'Big Data Hadoop',
#  'Full Stack Developer',
#  'iOS developer',
#  'Reuired urgently python Developer for Andheri location',
#  'Java Developer',
#  'Looking For Core Java Freshers',
#  'Duck Creek policy',
#  'Big Data Hadoop',
# ...

# %%
company_list
flatten_matrix2 = [val for sublist in company_list for val in sublist] 
flatten_matrix2
# Out:
# ['URS Systems Private Limited',
#  'Yashodha S M (Proprietor Of Co Inter Technology)',
#  'Delivery Centric Technology Services Private Limited',
#  'Company Name Confidential',
#  'Macropace Technologies',
#  'Sharp Point HR Consulting',
#  'C P Careers Private Limited',
#  'Accion Labs India Private Limited',
#  'Infomedia Solutions And Consultant',
#  'Klaus It Solutions Private Limited',
#  'Kameda Infologics Private Limited',
#  'Infomedia Solutions And Consultant',
#  'Saar IT Resources Private Limited',
#  'Numeric Technologies Incorporation',
#  'Infopro solutions pvt ltd',
#  'Infopro solutions pvt ltd',
#  'URS Systems Private Limited',
#  'URS Systems Private Limited',
#  'Sanda Office Management Services Private Limited',
#  'Company Name Confidential',
#  'Infopro solutions pvt ltd',
#  'Yashodha S M (Proprietor Of Co Inter Technology)',
#  'Saransh Software Solutions Private Limited',
#  'Corascent',
#  'Intellect Design Arena Limited',
# ...

# %%
location_list
flatten_matrix3 = [val for sublist in location_list for val in sublist] 
flatten_matrix3
# Out:
# ['Bengaluru / Bangalore',
#  'Delhi',
#  'Bengaluru / Bangalore',
#  'Indore',
#  'Bengaluru / Bangalore',
#  'Delhi',
#  'Bengaluru / Bangalore, Kolkata',
#  'Bengaluru / Bangalore',
#  'Pune',
#  'Bengaluru / Bangalore',
#  'Delhi, Thiruvananthapuram / Trivandrum',
#  'Pune',
#  'Mumbai City',
#  'Hyderabad / Secunderabad',
#  'Thiruvananthapuram / Trivandrum',
#  'Thiruvananthapuram / Trivandrum',
#  'Bengaluru / Bangalore',
#  'Bengaluru / Bangalore',
#  'Mumbai, Mumbai City, Navi Mumbai',
#  'Mumbai, Mumbai City, Navi Mumbai, Thane',
#  'Bengaluru / Bangalore',
#  'Erode',
#  'Bengaluru / Bangalore, Chennai',
#  'Bengaluru / Bangalore, Pune',
#  'Chennai, Hyderabad / Secunderabad',
#  'Mumbai, Mumbai City, Navi Mumbai',
#  'Mumbai, Mumbai City, Navi Mumbai, Thane',
#  'Bengaluru / Bangalore',
#  'Erode',
#  'Bengaluru / Bangalore, Chennai',
#  'Bengaluru / Bangalore, Pune',
#  'Chennai, Hyderabad / Secunderabad',
#  'Kolkata',
#  'Bengaluru / Bangalore',
# ...

# %%
ratess
flatten_matrix4 = [val for sublist in rates for val in sublist] 
flatten_matrix4
# Out:
# ['4-5 Years',
#  '0-4 Years',
#  '3-5 Years',
#  '1-5 Years',
#  '8-13 Years',
#  '4-8 Years',
#  '6-12 Years',
#  '5-15 Years',
#  '2-4 Years',
#  '5-8 Years',
#  '2-6 Years',
#  '1-5 Years',
#  '1-4 Years',
#  '9-19 Years',
#  '2-4 Years',
#  '2-6 Years',
#  '5-8 Years',
#  '4-7 Years',
#  '3-6 Years',
#  '3-6 Years',
#  '3-7 Years',
#  '0-1 Years',
#  '8-10 Years',
#  '4-9 Years',
#  '4-8 Years',
#  '3-6 Years',
#  '3-6 Years',
#  '3-7 Years',
#  '0-1 Years',
#  '8-10 Years',
#  '4-9 Years',
#  '4-8 Years',
#  '2-5 Years',
#  '6-11 Years',
#  '5-10 Years',
#  '2-12 Years',
#  '3-10 Years',
#  '2-7 Years',
#  '2-4 Years',
#  '3-10 Years',
#  '4-8 Years',
#  '0-1 Years',
#  '5-8 Years',
#  '0-2 Years',
#  '3-8 Years',
#  '0-3 Years',
#  '4-12 Years',
#  '0-4 Years',
#  '0-5 Years',
#  '5-7 Years',
#  '2-5 Years',
#  '2-4 Years',
#  '4-9 Years',
#  '4-9 Years',
#  '3-7 Years',
#  '0-2 Years',
#  '2-6 Years',
#  '0-1 Years',
#  '0-2 Years',
#  '0-2 Years',
#  '4-8 Years',
# ...

# %%
ratess
flatten_matrix5 = [val for sublist in pack2 for val in sublist] 
flatten_matrix5
# Out:
# ['6,00,000-10,00,000 INR',
#  '2,50,000-4,00,000 INR',
#  'Not Specified',
#  '1,80,000-3,60,000 INR',
#  '0-16,00,000 INR',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  '3,00,000-6,00,000 INR',
#  'Not Specified',
#  'Not Specified',
#  '1,80,000-3,20,000 INR',
#  '2,20,000-4,50,000 INR',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  '10,00,000-15,10,000 INR',
#  '10,10,000-15,00,000 INR',
#  '3,00,000-6,00,000 INR',
#  '3,00,000-5,00,000 INR',
#  'Not Specified',
#  '1,50,000-2,50,000 INR',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  '3,00,000-6,00,000 INR',
#  '3,00,000-5,00,000 INR',
#  'Not Specified',
#  '1,50,000-2,50,000 INR',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  '2,00,000-10,00,000 INR',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  '5,50,000-11,80,000 INR',
#  'Not Specified',
#  'Not Specified',
#  '1,50,000-2,20,000 INR',
# ...

# %%
skill
flatten_matrix6 = [val for sublist in skill1 for val in sublist] 
flatten_matrix6
# Out:
# ['6,00,000-10,00,000 INR',
#  '2,50,000-4,00,000 INR',
#  'Not Specified',
#  '1,80,000-3,60,000 INR',
#  '0-16,00,000 INR',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  '3,00,000-6,00,000 INR',
#  'Not Specified',
#  'Not Specified',
#  '1,80,000-3,20,000 INR',
#  '2,20,000-4,50,000 INR',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  '10,00,000-15,10,000 INR',
#  '10,10,000-15,00,000 INR',
#  '3,00,000-6,00,000 INR',
#  '3,00,000-5,00,000 INR',
#  'Not Specified',
#  '1,50,000-2,50,000 INR',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  '3,00,000-6,00,000 INR',
#  '3,00,000-5,00,000 INR',
#  'Not Specified',
#  '1,50,000-2,50,000 INR',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  '2,00,000-10,00,000 INR',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  '5,50,000-11,80,000 INR',
#  'Not Specified',
#  'Not Specified',
#  '1,50,000-2,20,000 INR',
# ...

# %%
ratess
flatten_matrix7 = [val for sublist in desc1 for val in sublist] 
flatten_matrix7
# Out:
# ['Work Location – Preferred Bangalore NP – Immediate to 2 weeks Mandatory Skills (4+Years’ Experience) Linux Scripting (Shell, Python etc) Networking Hands-on knowledge of ECE / MSDP Working with configurations on applications, DB connections, troubles',
#  'Position: SQL Server Developer! Essential Skills: SQL Server, SSIS development, T-SQL, Views, Stored Procedures, Functions and Triggers. Additional Skills: Oracle PL/ SQL.',
#  'Mean Stack Developer',
#  'Hi, Hiring for PHP Developer Exp : 1-2 Years Salary - 15-18k Exp : 2-3 Years Salary : 20-26k ( PHP - CI / Laravel / Ajax / Javascript) Location - Indore Interested? share resume at [HIDDEN TEXT] or call – 8368765353',
#  'Sap BW&Hana&ABAP',
#  '• The Software Developer is responsible for designing and architecting the software products. • The Software Developer is responsible to understand the current and proposed product offerings by company and come up with secure, robust and scalabl',
# ...

# %%
print(len(flatten_matrix1),len(flatten_matrix2),len(flatten_matrix3),len(flatten_matrix4),len(flatten_matrix5),len(flatten_matrix6),len(flatten_matrix7))
# Out:
# 125 125 125 125 125 125 125

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['Job Title']=flatten_matrix1
jobs['Company']=flatten_matrix2
jobs['Location']=flatten_matrix3
jobs['years']=flatten_matrix4
jobs['Package']=flatten_matrix5
jobs['Description']=flatten_matrix7

# %%
jobs
# Out:
#                                Job Title  \
# 0                          Systems Admin
# 1        Hiring For SQL Server Developer
# 2                   Mean Stack Developer
# 3                          PHP Developer
# 4                       Sap BW&Hana&ABAP
# ..                                   ...
# 120                 Salesforce Developer
# 121          Senior Full Stack Developer
# 122                   Mulesoft Developer
# 123  Senior Software Engineer - Java/AWS
# 124                    ASP.NET Developer
#
#                                                Company  \
# 0                          URS Systems Private Limited
# 1     Yashodha S M (Proprietor Of Co Inter Technology)
# 2    Delivery Centric Technology Services Private L...
# 3                            Company Name Confidential
# 4                               Macropace Technologies
# ..                                                 ...
# 120               IT-Scient Consulting Private Limited
# ...

# %%
#same the dataframe in the form of csv files

# %%
jobs.to_csv("q9.csv", index= False)

# %% [markdown]
# # question-10 Write a python program to scrape ‘data scientist’ job listings for location ‘New Delhi’ from ‘Monster.com’. It should include all the jobs listed for the next 5 pages.

# %% [raw]
# #First let's write some code to grab the HTML from the web page, and look at how we can start parsing through it. The following code will send a GET request to the web page we want.

# %%
#Fetch the main URL HTML code.

url="https://www.monsterindia.com/srp/results?query=Data%20Scientist&locations=Delhi&searchId=0cc88612-1356-46dc-8deb-db59f65c027b"

# %%
driver.get(url)

# %% [raw]
# #You can also provide different arguments to find_all, such as regular expressions or tag attributes to filter your search as specifically as you want.

# %%
n=int(input("Enter number of pages to be retained"))
# Out:
# Enter number of pages to be retained5

# %%
job_titles=[]
company_list=[]
location_list=[]
experience=[]
titles_tags=[]
company_tag=[]
location_tag=[]
year=[]
year1=[]
packg=[]
packg1=[]

# %%
#srp-right-part > div > div.srp-left > div:nth-child(1) > div:nth-child(3) > div > div> div > div.card-body.card-body-apply.pd10 > div > div > div > div.package.col-xxs-12.col-sm-4.text-ellipsis > span

# %%
for i in range(n):
    titles_tags=driver.find_elements_by_css_selector("#srp-right-part > div > div.srp-left > div:nth-child(1) > div:nth-child(3) > div > div > div > div.card-body.card-body-apply.pd10 > div > div > h3")
    job_titles.append(list(map(lambda x:x.text,titles_tags)))
    company_tag=driver.find_elements_by_css_selector("#srp-right-part > div > div.srp-left > div:nth-child(1) > div:nth-child(3) > div > div> div > div.card-body.card-body-apply.pd10 > div > div > span")
    company_list.append(list(map(lambda x:x.text,company_tag)))
    location_tag=driver.find_elements_by_css_selector("#srp-right-part > div > div.srp-left > div:nth-child(1) > div:nth-child(3) > div > div > div > div.card-body.card-body-apply.pd10 > div > div > div > div.col-xxs-12.col-sm-5.text-ellipsis > span")
    location_list.append(list(map(lambda x:x.text,location_tag)))
    year=driver.find_elements_by_css_selector("#srp-right-part > div > div.srp-left > div:nth-child(1) > div:nth-child(3) > div > div> div > div.card-body.card-body-apply.pd10 > div > div > div > div.exp.col-xxs-12.col-sm-3.text-ellipsis > span > small")
    year1.append(list(map(lambda x:x.text,year)))
    packg=driver.find_elements_by_css_selector("#srp-right-part > div > div.srp-left > div:nth-child(1) > div:nth-child(3) > div > div> div > div.card-body.card-body-apply.pd10 > div > div > div > div.package.col-xxs-12.col-sm-4.text-ellipsis > span")
    packg1.append(list(map(lambda x:x.text,packg)))
    driver.find_element_by_css_selector("#srp-right-part > div > div.srp-left > div:nth-child(1) > div:nth-child(4) > div > div > a:nth-child(2) > button").click()
    time.sleep(10)

# %%
job_titles
# Out:
# [['SOFTWARE ARCHITECT / IT ARCHITECT / TECH ARCHITECT\nsponsored',
#   'Data Analyst – Fresher – Data Scientist – Graduate - Fresher 8077828639 | 7303778896',
#   'Data Analyst – Fresher – Data Scientist – Graduate - Fresher 7303778896',
#   'Data Analyst – Fresher – Data Scientist – Graduate - Fresher 7303778896 | 9560245147',
#   'Data Analyst / Fresher / Data Scientist / Graduate Fresher - MNC - 7303778896 | 9560245147',
#   'Data Analyst / Fresher / Data Scientist / Graduate Fresher - MNC - 7303778896 | 9560245147',
#   'Data Analyst / Fresher / Data Scientist / Graduate Fresher - MNC - 7303778896 | 9560245147',
#   'Data Analyst / Fresher / Data Scientist / Graduate Fresher - MNC - 7303778896 | 9560245147',
#   'Data Analyst / Fresher / Data Scientist / Graduate Fresher - MNC - 7303778896 | 9560245147',
#   'Data Analyst – Fresher – Data Scientist – Graduate - Fresher 7303778896 | 9560245147 | 6397800351',
# ...

# %%
company_list
# Out:
# [['Promax Legal Solution Private Limited',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Company Name Confidential',
#   'Aryan Solutions Pte Ltd',
#   'Company Name Confidential',
#   'Company Name Confidential',
# ...

# %%
location_list
# Out:
# [['Delhi, Mohali',
#   'Delhi, Gurgaon / Gurugram',
#   'Delhi, Noida',
#   'Delhi, Noida',
#   'Delhi, Noida',
#   'Delhi, Gurgaon / Gurugram',
#   'Delhi, Ghaziabad',
#   'Delhi, Gurgaon / Gurugram',
#   'Delhi, Ghaziabad',
#   'Delhi, Gurgaon / Gurugram',
#   'Delhi, Noida',
#   'Delhi, Noida',
#   'Chennai, Delhi',
#   'Delhi, Lucknow',
#   'Chennai, Delhi',
#   'Ahmedabad, Delhi',
#   'Delhi, Noida',
#   'Delhi, Gurgaon / Gurugram',
#   'Delhi',
#   'Ahmedabad, Delhi',
#   'Delhi, Noida',
#   'Delhi',
#   'Delhi',
#   'Ahmedabad, Delhi',
#   'Delhi',
#   'Delhi, Faridabad'],
#  ['Delhi, Hyderabad / Secunderabad',
#   'Delhi, Kashipur',
#   'Delhi, Kolkata',
#   'Delhi, Mandya',
#   'Delhi, Hyderabad / Secunderabad',
#   'Delhi',
#   'Delhi, Pune',
#   'Delhi',
#   'Delhi, Gurgaon / Gurugram',
#   'Delhi, Hyderabad / Secunderabad',
#   'Ahmedabad, Delhi',
#   'Bengaluru / Bangalore, Delhi',
#   'Chennai, Delhi',
#   'Delhi, Hyderabad / Secunderabad',
# ...

# %%
#convert 2d in to 1D

# %%
job_titles
flatten_matrix1 = [val for sublist in job_titles for val in sublist] 
flatten_matrix1
# Out:
# ['SOFTWARE ARCHITECT / IT ARCHITECT / TECH ARCHITECT\nsponsored',
#  'Data Analyst – Fresher – Data Scientist – Graduate - Fresher 8077828639 | 7303778896',
#  'Data Analyst – Fresher – Data Scientist – Graduate - Fresher 7303778896',
#  'Data Analyst – Fresher – Data Scientist – Graduate - Fresher 7303778896 | 9560245147',
#  'Data Analyst / Fresher / Data Scientist / Graduate Fresher - MNC - 7303778896 | 9560245147',
#  'Data Analyst / Fresher / Data Scientist / Graduate Fresher - MNC - 7303778896 | 9560245147',
#  'Data Analyst / Fresher / Data Scientist / Graduate Fresher - MNC - 7303778896 | 9560245147',
#  'Data Analyst / Fresher / Data Scientist / Graduate Fresher - MNC - 7303778896 | 9560245147',
#  'Data Analyst / Fresher / Data Scientist / Graduate Fresher - MNC - 7303778896 | 9560245147',
#  'Data Analyst – Fresher – Data Scientist – Graduate - Fresher 7303778896 | 9560245147 | 6397800351',
# ...

# %%
company_list
flatten_matrix2 = [val for sublist in company_list for val in sublist] 
flatten_matrix2
# Out:
# ['Promax Legal Solution Private Limited',
#  'Structured Learning Assistance Consultants India Private Limited',
#  'Structured Learning Assistance Consultants India Private Limited',
#  'Structured Learning Assistance Consultants India Private Limited',
#  'Structured Learning Assistance Consultants India Private Limited',
#  'Structured Learning Assistance Consultants India Private Limited',
#  'Structured Learning Assistance Consultants India Private Limited',
#  'Structured Learning Assistance Consultants India Private Limited',
#  'Structured Learning Assistance Consultants India Private Limited',
#  'Structured Learning Assistance Consultants India Private Limited',
#  'Structured Learning Assistance Consultants India Private Limited',
#  'Structured Learning Assistance Consultants India Private Limited',
#  'Company Name Confidential',
#  'Aryan Solutions Pte Ltd',
#  'Company Name Confidential',
#  'Company Name Confidential',
#  'Advance Jobs Private Limited',
# ...

# %%
location_list
flatten_matrix3 = [val for sublist in location_list for val in sublist] 
flatten_matrix3
# Out:
# ['Delhi, Mohali',
#  'Delhi, Gurgaon / Gurugram',
#  'Delhi, Noida',
#  'Delhi, Noida',
#  'Delhi, Noida',
#  'Delhi, Gurgaon / Gurugram',
#  'Delhi, Ghaziabad',
#  'Delhi, Gurgaon / Gurugram',
#  'Delhi, Ghaziabad',
#  'Delhi, Gurgaon / Gurugram',
#  'Delhi, Noida',
#  'Delhi, Noida',
#  'Chennai, Delhi',
#  'Delhi, Lucknow',
#  'Chennai, Delhi',
#  'Ahmedabad, Delhi',
#  'Delhi, Noida',
#  'Delhi, Gurgaon / Gurugram',
#  'Delhi',
#  'Ahmedabad, Delhi',
#  'Delhi, Noida',
#  'Delhi',
#  'Delhi',
#  'Ahmedabad, Delhi',
#  'Delhi',
#  'Delhi, Faridabad',
#  'Delhi, Hyderabad / Secunderabad',
#  'Delhi, Kashipur',
#  'Delhi, Kolkata',
#  'Delhi, Mandya',
#  'Delhi, Hyderabad / Secunderabad',
#  'Delhi',
#  'Delhi, Pune',
#  'Delhi',
#  'Delhi, Gurgaon / Gurugram',
#  'Delhi, Hyderabad / Secunderabad',
#  'Ahmedabad, Delhi',
#  'Bengaluru / Bangalore, Delhi',
#  'Chennai, Delhi',
#  'Delhi, Hyderabad / Secunderabad',
#  'Delhi, Mumbai, Mumbai City, Navi Mumbai, Thane',
#  'Delhi',
# ...

# %%
flatten_matrix5 = [val for sublist in packg1 for val in sublist] 
flatten_matrix5
# Out:
# ['Not Specified',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  '3,00,000-8,00,000 INR',
#  '3,00,000-8,00,000 INR',
#  '3,00,000-8,00,000 INR',
#  '1,10,000-5,40,000 INR',
#  '5,50,000-8,50,000 INR',
#  'Not Specified',
#  '1,20,000-3,50,000 INR',
#  '1,20,000-7,50,000 INR',
#  'Not Specified',
#  '2,00,000-3,40,000 INR',
#  '3,20,000-4,30,000 INR',
#  '2,10,000-3,50,000 INR',
#  '3,20,000-4,30,000 INR',
#  'Not Specified',
#  '3,60,000-5,90,000 INR',
#  '1,30,000-2,40,000 INR',
#  'Not Specified',
#  '2,20,000-3,50,000 INR',
#  'Not Specified',
#  '6,00,000-8,00,000 INR',
#  '4,50,000-6,50,000 INR',
#  '2,50,000-4,00,000 INR',
#  'Not Specified',
#  'Not Specified',
#  '2,50,000-4,50,000 INR',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  'Not Specified',
#  '2,00,000-2,50,000 INR',
# ...

# %%
print(len(flatten_matrix1),len(flatten_matrix2),len(flatten_matrix3),len(flatten_matrix4),len(flatten_matrix5))
# Out:
# 126 126 126 125 126

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['Job Title']=flatten_matrix1[0:125]
jobs['Company']=flatten_matrix2[0:125]
jobs['Location']=flatten_matrix3[0:125]
jobs['year']=flatten_matrix4[0:125]
jobs['Package']=flatten_matrix5[0:125]

# %%
jobs.head(10)
# Out:
#                                            Job Title  \
# 0  SOFTWARE ARCHITECT / IT ARCHITECT / TECH ARCHI...
# 1  Data Analyst – Fresher – Data Scientist – Grad...
# 2  Data Analyst – Fresher – Data Scientist – Grad...
# 3  Data Analyst – Fresher – Data Scientist – Grad...
# 4  Data Analyst / Fresher / Data Scientist / Grad...
# 5  Data Analyst / Fresher / Data Scientist / Grad...
# 6  Data Analyst / Fresher / Data Scientist / Grad...
# 7  Data Analyst / Fresher / Data Scientist / Grad...
# 8  Data Analyst / Fresher / Data Scientist / Grad...
# 9  Data Analyst – Fresher – Data Scientist – Grad...
#
#                                              Company  \
# 0              Promax Legal Solution Private Limited
# 1  Structured Learning Assistance Consultants Ind...
# 2  Structured Learning Assistance Consultants Ind...
# 3  Structured Learning Assistance Consultants Ind...
# 4  Structured Learning Assistance Consultants Ind...
# 5  Structured Learning Assistance Consultants Ind...
# ...

# %%
#same the dataframe in the form of csv files

# %%
jobs.to_csv("q10.csv", index= False)

# %% [raw]
# conclusion:
#
# 1. Web scraping is one of the essential skills a data scientist needs. And it can’t be any easier than with using Python, 2. Requests, and BeautifulSoup.
# We can never trust full automation, sometimes we will need to go through the final result a recheck for abnormal information manually.
