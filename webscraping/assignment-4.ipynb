# %% [markdown]
# # Write a python program to scrap book name, author name, genre and book review of any 5 books from ‘www.bookpage.com’

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get("https://bookpage.com/features/25856-2021-preview-most-anticipated-ya#.X_s8LtgzbIU")

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang=\'en\' xmlns:fb=\'http://www.facebook.com/2008/fbml\' xmlns:og=\'http://opengraphprotocol.org/schema/\'>\n<head>\n<title>2021 preview: Most anticipated YA | BookPage</title>\n<meta name="description" content="Our list of the YA books we can&#39;t wait to discover in 2021 has something for everyone.">\n<link rel="canonical" href="https://bookpage.com/features/25856-2021-preview-most-anticipated-ya">\n<meta property="og:site_name" content="BookPage.com">\n<meta property="og:title" content="2021 preview: Most anticipated YA">\n<meta property="og:description" content="Our list of the YA books we can&#39;t wait to discover in 2021 has something for everyone.">\n<meta property="og:type" content="article">\n<meta property="og:url" content="https://bookpage.com/features/25856-2021-preview-most-anticipated-ya">\n<meta property="og:image" content="https://t1.bookpage.com/features/images/60d81f629827dc42f70ece4b79334891/medium.jpg">\n<meta name="twitter:card" conte
# ...

# %%
soup=BeautifulSoup(page.content,'html.parser')

# %%
value=soup.select_one("")

# %%
value
